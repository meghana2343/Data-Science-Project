# %% [markdown]
# <a href="https://colab.research.google.com/github/meghana2343/Data-Science-Project/blob/meghana2343-patch-1/stockprediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
dataset=pd.read_csv('HistoricalData_1761495123702.csv')
dataset.head()
# Out:
#          Date Close/Last    Volume     Open      High      Low
# 0  10/24/2025    $224.21  38685050  $221.97   $225.40  $221.90
# 1  10/23/2025    $221.09  31540000  $219.00   $221.30  $218.18
# 2  10/22/2025    $217.95  44308540  $219.30  $220.005  $216.52
# 3  10/21/2025    $222.03  50494570  $218.43   $223.32  $217.99
# 4  10/20/2025    $216.48  38882820  $213.88   $216.69  $213.59

# %%
dataset.shape
# Out:
# (126, 6)

# %%
#preprocessing data

# %%
dataset.isna().sum()
# Out:
# Date          0
# Close/Last    0
# Volume        0
# Open          0
# High          0
# Low           0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        126 non-null    object
#  1   Close/Last  126 non-null    object
#  2   Volume      126 non-null    int64
#  3   Open        126 non-null    object
#  4   High        126 non-null    object
#  5   Low         126 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 6.0+ KB

# %%
#converting the 'Date' column into 'datetime' dtype
dataset['Date'] = pd.to_datetime(dataset['Date'])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        126 non-null    datetime64[ns]
#  1   Close/Last  126 non-null    object
#  2   Volume      126 non-null    int64
#  3   Open        126 non-null    object
#  4   High        126 non-null    object
#  5   Low         126 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 6.0+ KB

# %%
#making the 'Date ' col as index
dataset.set_index('Date',inplace=True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 126 entries, 2025-10-24 to 2025-04-28
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Close/Last  126 non-null    object
#  1   Volume      126 non-null    int64
#  2   Open        126 non-null    object
#  3   High        126 non-null    object
#  4   Low         126 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 5.9+ KB

# %%
dataset.head()
# Out:
#            Close/Last    Volume     Open      High      Low
# Date
# 2025-10-24    $224.21  38685050  $221.97   $225.40  $221.90
# 2025-10-23    $221.09  31540000  $219.00   $221.30  $218.18
# 2025-10-22    $217.95  44308540  $219.30  $220.005  $216.52
# 2025-10-21    $222.03  50494570  $218.43   $223.32  $217.99
# 2025-10-20    $216.48  38882820  $213.88   $216.69  $213.59

# %%
#sorting the indexes
dataset.sort_index(inplace=True)

# %%
# Remove $ and convert selected columns to numeric
cols = ['Close/Last', 'Open', 'High', 'Low']
for col in cols:
    dataset[col] = dataset[col].replace({r'\$': ''}, regex=True).astype(float)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\$'
# <>:4: SyntaxWarning: invalid escape sequence '\$'
# /tmp/ipython-input-3218160304.py:4: SyntaxWarning: invalid escape sequence '\$'
#   dataset[col] = dataset[col].replace({'\$': ''}, regex=True).astype(float)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 126 entries, 2025-04-28 to 2025-10-24
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   
#        [0.66239316, 0.16390556, 0.64197308, 0.66226766, 0.67917482],
#        [0.59401709, 0.24168372, 0.60321619, 0.63698885, 0.60021341],
#        [0.57878112, 0.24409837, 0.62245912, 0.6070632 , 0.60128046],
#        [0.55834262, 0.20949708, 0.60529406, 0.62342007, 0.60394985],
#        [0.53177258, 0.24486537, 0.58523805, 0.55297398, 0.57229237],
#        [0.59568933, 0.17453055, 0.57295149, 0.58810409, 0.61781967],
#        [0.69881085, 0.28949346, 0.65516307, 0.71133829, 0.69606971],
#        [0.6230026 , 0.22824826, 0.67088265, 0.64972119, 0.66992709],
#        [0.68134522, 0.10183248, 0.6654621 , 0.67379182, 0.69944869],
#        [0.73931624, 0.17257252, 0.71912549, 0.75      , 0.76560555]])

# %%
dataset_scaled=pd.DataFrame(scaler_values,columns=dataset.columns, index=dataset.index)

# %%
dataset_scaled.head()
# Out:
#             Close/Last    Volume      Open      High       Low
# Date
# 2025-04-28    0.060944  0.118512  0.143373  0.096097  0.107327
# 2025-04-29    0.055184  0.202098  0.032885  0.055126  0.085897
# 2025-04-30    0.000000  0.335848  0.000000  0.000000  0.000000
# 2025-05-01    0.107395  0.524844  0.152859  0.125597  0.153832
# 2025-05-02    0.103307  0.560857  0.167404  0.145539  0.134270

# %%
#plotting columns
plt.rcParams['figure.figsize']=(15,5)
figure,ax=plt.subplots(5)

for ax,col in zip(ax,dataset_scaled.columns):
    ax.plot(dataset_scaled[col])
    ax.set_title(col)
    ax.axes.get_xaxis().set_visible(False)

# %%
## creating the sliding window sequence

def create_sequences(data,window_size):
    x = []
    y = []
    for i in range(window_size, len(data)):
        x.append(data.iloc[i-window_size:i].values)
        y.append(data.iloc[i].values)
    return np.array(x),np.array(y)

# %%
window_size=50
x, y = create_sequences(dataset_scaled, 30)

# %%
x.shape, y.shape
# Out:
# ((96, 30, 5), (96, 5))

# %%
x
# Out:
# array([[[0.06094389, 0.11851226, 0.14337339, 0.09609665, 0.10732705],
#         [0.05518395, 0.20209809, 0.03288463, 0.05512639, 0.08589721],
#         [0.        , 0.33584762, 0.        , 0.        , 0.        ],
#         ...,
#         [0.43645485, 0.30419253, 0.49471497, 0.51598513, 0.51058154],
#         [0.54162022, 0.18393292, 0.54621014, 0.53568587, 0.5628668 ],
#         [0.60497956, 0.16680494, 0.58867106, 0.60966543, 0.60519296]],
#
#        [[0.05518395, 0.20209809, 0.03288463, 0.05512639, 0.08589721],
#         [0.        , 0.33584762, 0.        , 0.        , 0.        ],
#         [0.10739502, 0.52484369, 0.15285934, 0.12559665, 0.15383247],
#         ...,
#         [0.54162022, 0.18393292, 0.54621014, 0.53568587, 0.5628668 ],
#         [0.60497956, 0.16680494, 0.58867106, 0.60966543, 0.60519296],
#         [0.61668525, 0.09948921, 0.62535008, 0.60669145, 0.62777877]],
#
#        [[0.        , 0.33584762, 0.        , 0.        , 0.        ],
#         [0.10739502, 0.52484369, 0.15285934, 0.12559665, 0.15383247],
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
x_train.shape, x_test.shape,
# Out:
# ((76, 30, 5), (20, 30, 5))

# %%
x_train.shape[1], x_train.shape[1]
# Out:
# (30, 30)

# %%
## lstm models
model= keras.Sequential([
    #adding firsr  lstm layers
    keras.layers.LSTM(units=52, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=True),
    keras.layers.Dropout(0.3),
    #adding second lstm layers
    keras.layers.LSTM(units=52, return_sequences=True),
    keras.layers.Dropout(0.3),
    #adding third lstm layers
    keras.layers.LSTM(units=52, return_sequences=False),
    keras.layers.Dropout(0.3),
    #adding output layers
    keras.layers.Dense(y_train.shape[1])



])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
#compilation
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['RootMeanSquaredError'])

# %%
#early stopping condition
early_stopping=EarlyStopping(monitor='val_loss',
                             patience=30,
                             restore_best_weights=True)

# %%
prediction = model.fit(x_train, y_train, epochs=100, batch_size=3, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - RootMeanSquaredError: 0.1183 - loss: 0.0140 - val_RootMeanSquaredError: 0.0719 - val_loss: 0.0052
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - RootMeanSquaredError: 0.1209 - loss: 0.0147 - val_RootMeanSquaredError: 0.0717 - val_loss: 0.0051
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - RootMeanSquaredError: 0.1277 - loss: 0.0164 - val_RootMeanSquaredError: 0.0706 - val_loss: 0.0050
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - RootMeanSquaredError: 0.1262 - loss: 0.0163 - val_RootMeanSquaredError: 0.0809 - val_loss: 0.0065
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - RootMeanSquaredError: 0.1147 - loss: 0.0133 - val_RootMeanSquaredError: 0.0731 - val_loss: 0.0053
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - RootMeanSquaredError: 0.1211 - loss: 0.0149 - val_RootMeanSquaredError: 0.0872 - val_loss: 0.0076
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - RootMeanSquaredError: 0.1372 - loss: 0.0189 - val_RootMeanSquaredError: 0.0651 - val_loss: 0.0042
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - RootMeanSquaredError: 0.1109 - loss: 0.0124 - val_RootMeanSquaredError: 0.0984 - val_loss: 0.0097
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - RootMeanSquaredError: 0.1249 - loss: 0.0157 - val_RootMeanSquaredError: 0.0691 - val_loss: 0.0048
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - RootMeanSquaredError: 0.1136 - loss: 0.0131 - val_RootMeanSquaredError: 0.0823 - val_loss: 0.0068
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - RootMeanSquaredError: 0.1288 - loss: 0.0168 - val_RootMeanSquaredError: 0.0715 - val_loss: 0.0051
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - RootMeanSquaredError: 0.1184 - loss: 0.0142 - val_RootMeanSquaredError: 0.0884 - val_loss: 0.0078
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - RootMeanSquaredError: 0.1198 - loss: 0.0144 - val_RootMeanSquaredError: 0.0759 - val_loss: 0.0058
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - RootMeanSquaredError: 0.1360 - loss: 0.0188 - val_RootMeanSquaredError: 0.0683 - val_loss: 0.0047
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - RootMeanSquaredError: 0.1172 - loss: 0.0139 - val_RootMeanSquaredError: 0.0672 - val_loss: 0.0045
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - RootMeanSquaredError: 0.1296 - loss: 0.0170 - val_RootMeanSquaredError: 0.0829 - val_loss: 0.0069
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - RootMeanSquaredError: 0.1250 - loss: 0.0157 - val_RootMeanSquaredError: 0.0706 - val_loss: 0.0050
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - RootMeanSquaredError: 0.0995 - loss: 0.0100 - val_RootMeanSquaredError: 0.0706 - val_loss: 0.0050
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - RootMeanSquaredError: 0.1212 - loss: 0.0148 - val_RootMeanSquaredError: 0.0745 - val_loss: 0.0055
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - RootMeanSquaredError: 0.1212 - loss: 0.0149 - val_RootMeanSquaredError: 0.0663 - val_loss: 0.0044
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - RootMeanSquaredError: 0.1226 - loss: 0.0151 - val_RootMeanSquaredError: 0.0750 - val_loss: 0.0056
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - RootMeanSquaredError: 0.1268 - loss: 0.0163 - val_RootMeanSquaredError: 0.0668 - val_loss: 0.0045
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - RootMeanSquaredError: 0.1050 - loss: 0.0111 - val_RootMeanSquaredError: 0.0898 - val_loss: 0.0081
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - RootMeanSquaredError: 0.1110 - loss: 0.0124 - val_RootMeanSquaredError: 0.0944 - val_loss: 0.0089
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - RootMeanSquaredError: 0.1465 - loss: 0.0217 - val_RootMeanSquaredError: 0.0653 - val_loss: 0.0043
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - RootMeanSquaredError: 0.1391 - loss: 0.0196 - val_RootMeanSquaredError: 0.0768 - val_loss: 0.0059
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - RootMeanSquaredError: 0.1301 - loss: 0.0170 - val_RootMeanSquaredError: 0.0854 - val_loss: 0.0073
# Epoch 28/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - RootMeanSquaredError: 0.1344 - loss: 0.0187 - val_RootMeanSquaredError: 0.0744 - val_loss: 0.0055
# Epoch 29/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - RootMeanSquaredError: 0.0999 - loss: 0.0102 - val_RootMeanSquaredError: 0.0894 - val_loss: 0.0080
# Epoch 30/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - RootMeanSquaredError: 0.1131 - loss: 0.0128 - val_RootMeanSquaredError: 0.0800 - val_loss: 0.0064
# Epoch 31/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - RootMeanSquaredError: 0.1217 - loss: 0.0150 - val_RootMeanSquaredError: 0.0843 - val_loss: 0.0071
# Epoch 32/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - RootMeanSquaredError: 0.1133 - loss: 0.0129 - val_RootMeanSquaredError: 0.0768 - val_loss: 0.0059
# Epoch 33/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - RootMeanSquaredError: 0.1009 - loss: 0.0103 - val_RootMeanSquaredError: 0.1008 - val_loss: 0.0102
# Epoch 34/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - RootMeanSquaredError: 0.1065 - loss: 0.0115 - val_RootMeanSquaredError: 0.0883 - val_loss: 0.0078
# Epoch 35/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - RootMeanSquaredError: 0.0991 - loss: 0.0100 - val_RootMeanSquaredError: 0.0678 - val_loss: 0.0046
# Epoch 36/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - RootMeanSquaredError: 0.1096 - loss: 0.0122 - val_RootMeanSquaredError: 0.0752 - val_loss: 0.0057
# Epoch 37/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - RootMeanSquaredError: 0.1204 - loss: 0.0146 - val_RootMeanSquaredError: 0.0847 - val_loss: 0.0072

# %%
predictions=model.predict(x_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s
#   0.004394373390823603,
#   0.005622871220111847,
#   0.004459613002836704,
#   0.008057136088609695,
#   0.008918063715100288,
#   0.004269815981388092,
#   0.005894575268030167,
#   0.007289501838386059,
#   0.005541098769754171,
#   0.007987887598574162,
#   0.00640060706064105,
#   0.007101720664650202,
#   0.005896261893212795,
#   0.010163526982069016,
#   0.0077959150075912476,
#   0.004597224295139313,
#   0.005660898517817259,
#   0.007182504516094923]}

# %%
##forecasting the data

predictions[:10]
# Out:
# array([[0.73302615, 0.1645456 , 0.7407782 , 0.74768245, 0.7523581 ],
#        [0.73818386, 0.18949652, 0.7432708 , 0.7591968 , 0.75956774],
#        [0.7326598 , 0.23202953, 0.74353594, 0.7610874 , 0.7517847 ],
#        [0.6582117 , 0.16234192, 0.6687227 , 0.6768594 , 0.68504226],
#        [0.857262  , 0.22499734, 0.88459945, 0.88184536, 0.8833041 ],
#        [0.7355324 , 0.17195944, 0.7418885 , 0.7519019 , 0.7552458 ],
#        [0.8580035 , 0.23559248, 0.88179433, 0.88340443, 0.8780029 ],
#        [0.7392435 , 0.17188653, 0.7290282 , 0.75724036, 0.7618543 ],
#        [0.47077513, 0.14859024, 0.5000223 , 0.4978661 , 0.52772856],
#        [0.5805483 , 0.19505914, 0.5998434 , 0.6082201 , 0.6200563 ]],
#       dtype=float32)

# %%
###inverse scaling


predictions_inverse = scaler.inverse_transform(predictions)
y_test_rescaled = scaler.inverse_transform(y_test)

# %%
predictions[:10]
# Out:
# array([[0.73302615, 0.1645456 , 0.7407782 , 0.74768245, 0.7523581 ],
#        [0.73818386, 0.18949652, 0.7432708 , 0.7591968 , 0.75956774],
#        [0.7326598 , 0.23202953, 0.74353594, 0.7610874 , 0.7517847 ],
#        [0.6582117 , 0.16234192, 0.6687227 , 0.6768594 , 0.68504226],
#        [0.857262  , 0.22499734, 0.88459945, 0.88184536, 0.8833041 ],
#        [0.7355324 , 0.17195944, 0.7418885 , 0.7519019 , 0.7552458 ],
#        [0.8580035 , 0.23559248, 0.88179433, 0.88340443, 0.8780029 ],
#        [0.7392435 , 0.17188653, 0.7290282 , 0.75724036, 0.7618543 ],
#        [0.47077513, 0.14859024, 0.5000223 , 0.4978661 , 0.52772856],
#        [0.5805483 , 0.19505914, 0.5998434 , 0.6082201 , 0.6200563 ]],
#       dtype=float32)

# %%
##3plotting the results

plt.figure(figsize=(14,7))
for i, col in enumerate(dataset_scaled.columns):
  plt.subplot(2,3, i+1)
  plt.plot(y_test_rescaled[:,i], color='blue', label = f'Actual{col}')
  plt.plot(predictions[:, i], color='red', label= f'predicted{col}')
  plt.title(f'{col} Prediction')
  plt.xlabel('Time')
  plt.ylabel(f'{col} Price')
  plt.legend()
  plt.tight_layout()
plt.show()

# %%
#  correlation matrix
corr = dataset.corr(numeric_only=True)

#  heatmap
plt.figure(figsize=(15, 5))
sns.heatmap(corr, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()
